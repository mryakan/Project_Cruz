# %%
from IPython.display import Image, display

# %%
image_file = "/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_large/A/a29ydW5pc2hpLnR0Zg==.png"
display(Image(filename=image_file))

# %%
% matplotlib inline

# %%
pickle_files = ['/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/A.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/B.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/C.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/D.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/E.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/F.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/G.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/H.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/I.pickle', '/mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/J.pickle']

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
for label, pickle_file in enumerate(pickle_files):
        try:
            with open(pickle_file, 'rb') as f:
                print("Loading %s as label %s" % (pickle_file, label))
                letter_set = pickle.load(f)
                plt.imshow(letter_set[np.random.randint(0,len(letter_set))])
                plt.title("label %s (%s)" % (label, str(pickle_file.split('/')[-1]).split('.')[0]))
                plt.show()
        except Exception as e:
            print('Unable to process data from', pickle_file, ':', e)
            raise
# Out:
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/A.pickle as label 0
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/B.pickle as label 1
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/C.pickle as label 2
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/D.pickle as label 3
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/E.pickle as label 4
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/F.pickle as label 5
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/G.pickle as label 6
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/H.pickle as label 7
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/I.pickle as label 8
# Loading /mnt/t/TEMP DOWNLOADS/Deep Learning Data Sets/notMNIST_small/J.pickle as label 9
